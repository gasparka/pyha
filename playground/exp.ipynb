# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

# 2hz signal
t = np.linspace(0,2, 512)
a = np.exp(1j * 2*np.pi*2 * t)

# 4hz signal
b = np.exp(1j * 2*np.pi*4 * t)

# %%
plt.plot(a)
plt.plot(b)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /home/gaspar/anaconda3/lib/python3.5/site-packages/numpy/core/numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
res = a*b
print(res)
plt.plot(a*b)
plt.show()
# Out:
# [ 1.00000000 +0.00000000e+00j  0.98913418 +1.47015533e-01j
#   0.95677287 +2.90836179e-01j  0.90361931 +4.28336480e-01j
#   0.83082863 +5.56528329e-01j  0.73998269 +6.72625910e-01j
#   0.63305572 +7.74106230e-01j  0.51237141 +8.58763958e-01j
#   0.38055244 +9.24759343e-01j  0.24046344 +9.70658197e-01j
#   0.09514877 +9.95463064e-01j -0.05223363 +9.98634892e-01j
#  -0.19848091 +9.80104754e-01j -0.34041488 +9.40275338e-01j
#  -0.47495107 +8.80012204e-01j -0.59916580 +8.00624968e-01j
#  -0.71035969 +7.03838843e-01j -0.80611629 +5.91757151e-01j
#  -0.88435467 +4.66815610e-01j -0.94337458 +3.31729404e-01j
#  -0.98189342 +1.89434175e-01j -0.99907412 +4.30222330e-02j
#  -0.99454330 -1.04324653e-01j -0.96839943 -2.49404393e-01j
#  -0.92121066 -3.89064169e-01j -0.85400247 -5.20268945e-01j
#  -0.76823542 -6.40167428e-01j -0.66577336 -7.46154026e-01j
#  -0.54884296 -8.35925479e-01j -0.41998530 -9.07530907e-01j
#  -0.28200068 -9.59414206e-01j -0.13788772 -9.90447867e-01j
# ...
