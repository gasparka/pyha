# %%
from wrapacc.model.acc import WrapAcc
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
from components.cordic.model.cordic import CORDIC
# %matplotlib inline

# %%
fs = 128
freq = 4
t = np.linspace(0, 1, fs, endpoint=False)
ref = (signal.sawtooth(2 * np.pi * freq * t) + 1) / 2
plt.plot(ref)

# %%
iterations = 18
c = CORDIC(iterations)

# x, y, _ = self.kernel(x=1 / 1.646760, y=0, phase=phase_acc, mode='ROTATE')
y = [c(1 / 1.646760, 0, phase, mode='ROTATE') for phase in ref]
# print(y)
y = np.transpose(y)

# %%
plt.plot(y[0])
plt.plot(-y[1])
plt.plot(y[1])
plt.plot(-y[0])
# plt.plot(ref)
# plt.plot(y[2] * np.pi)
